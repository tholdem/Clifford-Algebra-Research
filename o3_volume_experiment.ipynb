# %%
import os
os.chdir('/')
if not os.path.exists("/clifford-group-equivariant-neural-networks"):
    # !git clone https://github.com/DavidRuhe/clifford-group-equivariant-neural-networks.git
os.chdir("/clifford-group-equivariant-neural-networks")

# %%
import torch
from torch import nn, optim
import torch.nn.functional as F
import engineer
import yaml
import argparse
import ast
import inspect
import os
import sys
import typing
from engineer.utils.load_module import load_module

# %%
argv = "o3.py -C configs/engineer/trainer.yaml -C configs/optimizer/adam.yaml -C configs/dataset/o3.yaml -C configs/model/o3_cgmlp.yaml --trainer.max_steps=131072 --trainer.val_check_interval=1024 --dataset.batch_size=128 --dataset.num_samples=65536 --model.hidden_features=96 --model.num_layers=4 --optimizer.lr=0.001"
argv = argv.split()
for i in range(len(argv)):
        if argv[i].startswith("--_"):
            argv[i] = argv[i].split("=", maxsplit=1)[1]
argv = [v for v_ in argv for v in v_.replace("'", "").split(" ")]

# %%
yamls = []
i = 0
while i < len(argv):
    if argv[i] == "-C":
        yamls.append(argv[i + 1])
        del argv[i]
        del argv[i]
    else:
        i += 1

print(yamls)
# Out:
# ['configs/engineer/trainer.yaml', 'configs/optimizer/adam.yaml', 'configs/dataset/o3.yaml', 'configs/model/o3_cgmlp.yaml']

# %%
config_dict = {}
for y in yamls:
    with open(y, "r") as f:
        config = yaml.load(f, yaml.SafeLoader)
        if config is not None:
            config_dict = config_dict | config

print(config_dict)
# Out:
# {'trainer': {'module': 'engineer.Trainer'}, 'optimizer': {'module': 'torch.optim.Adam'}, 'dataset': {'module': 'data.o3.O3Dataset'}, 'model': {'module': 'models.o3_cgmlp.O3CGMLP'}}

# %%
parser = argparse.ArgumentParser()
parser.add_argument("--seed", type=int, default=42)
# Out:
# _StoreAction(option_strings=['--seed'], dest='seed', nargs=None, const=None, default=42, type=<class 'int'>, choices=None, required=False, help=None, metavar=None)

# %%
def string_to_list(s):
    # Try to convert the string directly
    try:
        return ast.literal_eval(s)
    except (ValueError, SyntaxError):
        # If that fails, assume the string represents a list of strings without quotes
        s = s.strip("[]").split(",")
        s = "[{}]".format(", ".join("'{}'".format(i.strip()) for i in s))
        return ast.literal_eval(s)


def try_literal_eval(v):
    if v.startswith("[") and v.endswith("]"):
        return string_to_list(v)

    try:
        return ast.literal_eval(v)
    except ValueError:
        return v
    except SyntaxError:
        return v


def get_type(v):
    if isinstance(v, bool):
        t = lambda x: (str(x).lower() == "true")
    else:
        t = type(v)
    return t


def pretty(d, indent=0):
    for k, v in d.items():
        if isinstance(v, dict):
            print("  " * indent + k)
            pretty(v, indent + 1)
        else:
            print("  " * indent + f"{k}: {v}")


def unflatten(dictionary, sep="."):
    result = dict()
    for k, v in dictionary.items():
        parts = k.split(sep)
        d = result
        for part in parts[:-1]:
            if part not in d:
                d[part] = dict()
            d = d[part]
        d[parts[-1]] = v
    return result


def check_optional(obj: typing.Any) -> bool:
    return (
        typing.get_origin(obj) is typing.Union
        and len(typing.get_args(obj)) == 2
        and typing.get_args(obj)[1] == type(None)
    )


def get_default_args(func):
    signature = inspect.signature(func)
    types = typing.get_type_hints(func)
    arguments = {}

    for k, v in signature.parameters.items():
        if v.default is inspect.Parameter.empty:
            continue

        if k in types and check_optional(types[k]):
            arguments[k] = None
        else:
            arguments[k] = v.default

    return arguments


def get_run_name(argv: list[str]):
    name_parts: list[str] = []
    for v in argv:
        if v.startswith("-C"):
            v = v[3:]
        if v.startswith("--"):
            name_parts.append(v[2:])
        elif os.path.exists(v):
            name_parts.append(os.path.splitext(os.path.basename(v))[0])

    return "_".join(name_parts)

# %%
print(config_dict)
# Out:
# {'trainer': {'module': 'engineer.Trainer'}, 'optimizer': {'module': 'torch.optim.Adam'}, 'dataset': {'module': 'data.o3.O3Dataset'}, 'model': {'module': 'models.o3_cgmlp.O3CGMLP'}}

# %%
for k in config_dict:
    if "module" in config_dict[k].keys():
        module = load_module(config_dict[k]["module"])
        argspec = get_default_args(module.__init__)
        group = parser.add_argument_group(k)
        v = config_dict[k].pop("module")

        group.add_argument(
            f"--{k}.module", default=v, type=str, help=f"Default: {v}"
        )
        for k_, v in argspec.items():
            if k_ in config_dict[k]:
                v = config_dict[k].pop(k_)

            if v.__class__.__module__ == "builtins":
                if v is None or isinstance(v, list):
                    t = try_literal_eval
                else:
                    t = get_type(v)

                group.add_argument(
                    f"--{k}.{k_}", default=v, type=t, help=f"Default: {v}"
                )

        if len(config_dict[k]) > 0:
            raise KeyError(
                f"Got unknown keys for {k} config: {tuple(config_dict[k].keys())}."
            )
    else:
        raise KeyError(f"Got unknown key: {k}.")

# %%
args = parser.parse_args(argv[1:])

config = unflatten(vars(args))

print("\nConfiguration\n---")
pretty(config)

name = get_run_name(sys.argv[1:])
experiment = os.path.splitext(os.path.basename(sys.argv[0]))[0]
# Out:
# Configuration
# ---
# seed: 42
# trainer
#   module: engineer.Trainer
#   scheduler: None
#   logger: None
#   max_steps: 131072
#   max_time: None
#   limit_val_batches: inf
#   val_check_interval: 1024
#   print_interval: 32
#   fast_dev_run: False
#   wandb: None
#   callbacks: []
#   log_interval: 256
#   checkpoint: None
#   test_only: False
# optimizer
#   module: torch.optim.Adam
#   lr: 0.001
#   betas: (0.9, 0.999)
#   eps: 1e-08
#   weight_decay: 0
#   amsgrad: False
#   foreach: None
#   maximize: False
#   capturable: False
#   differentiable: False
#   fused: None
# dataset
#   module: data.o3.O3Dataset
#   num_samples: 65536
#   batch_size: 128
# model
#   module: models.o3_cgmlp.O3CGMLP
#   in_features: 3
#   hidden_features: 96
#   out_features: 1
#   num_layers: 4
#   init_normalization: 0

# %%
import os
import socket
import tempfile
from typing import Any, Callable

import torch
import torch.distributed as dist

from engineer.utils.seed import set_seed

USE_DISTRIBUTED = "NCCL_SYNC_FILE" in os.environ or "TORCHELASTIC_RUN_ID" in os.environ

def _ddp_setup():
    if "CUDA_VISIBLE_DEVICES" not in os.environ:
        raise ValueError("Cannot initialize NCCL without visible CUDA devices.")

    hostname = socket.gethostname()
    print(f"Setting up DDP on {hostname}.")
    if "TORCHELASTIC_RUN_ID" in os.environ:
        print("TorchElastic detected.")
        _setup = _setup_torchelastic
    elif "NCCL_SYNC_FILE" in os.environ:
        print("Detected NCCL_SYNC_FILE. Assuming SLURM cluster.")
        _setup = _setup_slurm
    else:
        raise ValueError("Unable to detect DDP setup.")

    rank, local_rank, world_size = _setup()

    print(
        f"{hostname} ready! Rank: {rank}. Local rank: {local_rank}. World size: {world_size}."
    )
    devices = os.environ["CUDA_VISIBLE_DEVICES"].split(",")
    device = f"cuda:{int(devices[local_rank])}"
    torch.cuda.set_device(device)

    assert dist.is_initialized()

    return {
        "rank": rank,
        "local_rank": local_rank,
        "world_size": world_size,
        "device": device,
    }

# %%
def main(config):
    dataset_config = config["dataset"]
    dataset = engineer.load_module(dataset_config.pop("module"))(**dataset_config)

    train_loader = dataset.train_loader()
    val_loader = dataset.val_loader()
    test_loader = dataset.test_loader()

    model_config = config["model"]
    model_module = engineer.load_module(model_config.pop("module"))
    model = model_module(**model_config)

    model = model.cuda()

    optimizer_config = config["optimizer"]
    optimizer = engineer.load_module(optimizer_config.pop("module"))(
        model.parameters(), **optimizer_config
    )

    trainer_module = engineer.load_module(config["trainer"].pop("module"))
    trainer_config = config["trainer"]
    scheduler = None
    trainer_config["scheduler"] = scheduler
    trainer = trainer_module(
        **trainer_config,
    )

    trainer.fit(model, optimizer, train_loader, val_loader, test_loader)

# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()

# Access the DATAROOT variable
dataroot = os.getenv("DATAROOT")
print(dataroot)
# Out:
# D:\Github\Clifford-Algebra-Research\datasets\

# %%
seed = config["seed"]

assert isinstance(seed, int)
seed = set_seed(seed)
tempdir = tempfile.TemporaryDirectory()

dist_cfg = None
if USE_DISTRIBUTED:
    dist_cfg = _ddp_setup()
config["dist"] = dist_cfg

main(config)

tempdir.cleanup()
if dist.is_initialized():
    dist.destroy_process_group()
# Out:
# Model Summary
# ---
# O3CGMLP(
#   (algebra): CliffordAlgebra()
#   (net): Sequential(
#     (0): FullyConnectedSteerableGeometricProductLayer(
#       (algebra): CliffordAlgebra()
#       (normalization): NormalizationLayer(
#         (algebra): CliffordAlgebra()
#       )
#       (linear_right): MVLinear(
#         (algebra): CliffordAlgebra()
#       )
#       (linear_left): MVLinear(
#         (algebra): CliffordAlgebra()
#       )
#     )
#     (1): MVSiLU(
#       (algebra): CliffordAlgebra()
#     )
#     (2): MVSiLU(
#       (algebra): CliffordAlgebra()
#     )
#     (3): MVSiLU(
#       (algebra): CliffordAlgebra()
#     )
#     (4): FullyConnectedSteerableGeometricProductLayer(
#       (algebra): CliffordAlgebra()
#       (normalization): NormalizationLayer(
#         (algebra): CliffordAlgebra()
#       )
#       (linear_right): MVLinear(
#         (algebra): CliffordAlgebra()
#       )
#       (linear_left): MVLinear(
#         (algebra): CliffordAlgebra()
#       )
#     )
#   )
# )
# Total parameters: 48.9K
#
# Step: 0 (Training) Loss: 0.0702
# Defined metric train/loss.
# Defined metric train/s_it.
# Defined metric train/lr.
# Defined metric train/epoch.
#
# train/loss: 0.0702
# train/s_it: 3.3314
# train/lr: 0.0010
# train/epoch: 0.0000
#
# Step: 0 (Validation) Batch: 0 / 128
# Step: 0 (Validation) Batch: 32 / 128
# Step: 0 (Validation) Batch: 64 / 128
# Step: 0 (Validation) Batch: 96 / 128
# Defined metric val/loss.
# Defined metric val/s_it.
#
# val/loss: 0.0708
# val/s_it: 0.0462
#
# Step: 0 (Testing) Batch: 0 / 128
# Step: 0 (Testing) Batch: 32 / 128
# Step: 0 (Testing) Batch: 64 / 128
# Step: 0 (Testing) Batch: 96 / 128
# Defined metric test/loss.
# Defined metric test/s_it.
#
# test/loss: 0.0724
# test/s_it: 0.0526
#
# Step: 32 (Training) Loss: 0.0050
# Step: 64 (Training) Loss: 0.0017
# Step: 96 (Training) Loss: 0.0009
# Step: 128 (Training) Loss: 0.0007
# Step: 160 (Training) Loss: 0.0006
# Step: 192 (Training) Loss: 0.0006
# Step: 224 (Training) Loss: 0.0003
# Step: 256 (Training) Loss: 0.0004
#
# train/loss: 0.0031
# train/s_it: 0.0556
# train/lr: 0.0010
# train/epoch: 0.0000
#
# Step: 288 (Training) Loss: 0.0002
# Step: 320 (Training) Loss: 0.0002
# Step: 352 (Training) Loss: 0.0001
# Step: 384 (Training) Loss: 0.0001
# Step: 416 (Training) Loss: 0.0001
# Step: 448 (Training) Loss: 0.0001
# Step: 480 (Training) Loss: 0.0001
# Step: 512 (Training) Loss: 0.0001
#
# train/loss: 0.0002
# train/s_it: 0.0401
# train/lr: 0.0010
# train/epoch: 1.0000
#
# Step: 544 (Training) Loss: 0.0001
# Step: 576 (Training) Loss: 0.0001
# Step: 608 (Training) Loss: 0.0000
# Step: 640 (Training) Loss: 0.0001
# Step: 672 (Training) Loss: 0.0001
# Step: 704 (Training) Loss: 0.0001
# Step: 736 (Training) Loss: 0.0001
# Step: 768 (Training) Loss: 0.0001
#
# train/loss: 0.0001
# train/s_it: 0.0284
# train/lr: 0.0010
# train/epoch: 1.0000
#
# Step: 800 (Training) Loss: 0.0001
# Step: 832 (Training) Loss: 0.0001
# Step: 864 (Training) Loss: 0.0001
# Step: 896 (Training) Loss: 0.0000
# Step: 928 (Training) Loss: 0.0000
# Step: 960 (Training) Loss: 0.0000
# Step: 992 (Training) Loss: 0.0001
# Step: 1024 (Training) Loss: 0.0000
#
# train/loss: 0.0001
# train/s_it: 0.0397
# train/lr: 0.0010
# train/epoch: 2.0000
#
# Step: 1024 (Validation) Batch: 0 / 128
# Step: 1024 (Validation) Batch: 32 / 128
# Step: 1024 (Validation) Batch: 64 / 128
# Step: 1024 (Validation) Batch: 96 / 128
#
# val/loss: 0.0000
# val/s_it: 0.0410
#
# Step: 1024 (Testing) Batch: 0 / 128
# Step: 1024 (Testing) Batch: 32 / 128
# Step: 1024 (Testing) Batch: 64 / 128
# Step: 1024 (Testing) Batch: 96 / 128
#
# test/loss: 0.0000
# test/s_it: 0.0427
#
# Step: 1056 (Training) Loss: 0.0000
# Step: 1088 (Training) Loss: 0.0000
# Step: 1120 (Training) Loss: 0.0000
# Step: 1152 (Training) Loss: 0.0000
# Step: 1184 (Training) Loss: 0.0000
# Step: 1216 (Training) Loss: 0.0000
# Step: 1248 (Training) Loss: 0.0000
# Step: 1280 (Training) Loss: 0.0000
#
# train/loss: 0.0000
# train/s_it: 0.
(Training) Loss: 0.0000
#
# train/loss: 0.0000
# train/s_it: 0.0398
# train/lr: 0.0010
# train/epoch: 249.0000
#
# Step: 127520 (Training) Loss: 0.0000
# Step: 127552 (Training) Loss: 0.0000
# Step: 127584 (Training) Loss: 0.0000
# Step: 127616 (Training) Loss: 0.0000
# Step: 127648 (Training) Loss: 0.0000
# Step: 127680 (Training) Loss: 0.0000
# Step: 127712 (Training) Loss: 0.0000
# Step: 127744 (Training) Loss: 0.0000
#
# train/loss: 0.0000
# train/s_it: 0.0277
# train/lr: 0.0010
# train/epoch: 249.0000
#
# Step: 127776 (Training) Loss: 0.0000
# Step: 127808 (Training) Loss: 0.0000
# Step: 127840 (Training) Loss: 0.0000
# Step: 127872 (Training) Loss: 0.0000
# Step: 127904 (Training) Loss: 0.0000
# Step: 127936 (Training) Loss: 0.0000
# Step: 127968 (Training) Loss: 0.0000
# Step: 128000 (Training) Loss: 0.0000
#
# train/loss: 0.0000
# train/s_it: 0.0397
# train/lr: 0.0010
# train/epoch: 250.0000
#
# Step: 128000 (Validation) Batch: 0 / 128
# Step: 128000 (Validation) Batch: 32 / 128
# Step: 128000 (Validation) Batch: 64 / 128
# Step: 128000 (Validation) Batch: 96 / 128
#
# val/loss: 0.0000
# val/s_it: 0.0408
#
# Step: 128032 (Training) Loss: 0.0000
# Step: 128064 (Training) Loss: 0.0000
# Step: 128096 (Training) Loss: 0.0000
# Step: 128128 (Training) Loss: 0.0000
# Step: 128160 (Training) Loss: 0.0000
# Step: 128192 (Training) Loss: 0.0000
# Step: 128224 (Training) Loss: 0.0000
# Step: 128256 (Training) Loss: 0.0000
#
# train/loss: 0.0000
# train/s_it: 0.0284
# train/lr: 0.0010
# train/epoch: 250.0000
#
# Step: 128288 (Training) Loss: 0.0000
# Step: 128320 (Training) Loss: 0.0000
# Step: 128352 (Training) Loss: 0.0000
# Step: 128384 (Training) Loss: 0.0000
# Step: 128416 (Training) Loss: 0.0000
# Step: 128448 (Training) Loss: 0.0000
# Step: 128480 (Training) Loss: 0.0000
# Step: 128512 (Training) Loss: 0.0000
#
# train/loss: 0.0000
# train/s_it: 0.0409
# train/lr: 0.0010
# train/epoch: 251.0000
#
# Step: 128544 (Training) Loss: 0.0000
# Step: 128576 (Training) Loss: 0.0000
# Step: 128608 (Training) Loss: 0.0000
# Step: 128640 (Training) Loss: 0.0000
# Step: 128672 (Training) Loss: 0.0000
# Step: 128704 (Training) Loss: 0.0000
# Step: 128736 (Training) Loss: 0.0000
# Step: 128768 (Training) Loss: 0.0000
#
# train/loss: 0.0000
# train/s_it: 0.0299
# train/lr: 0.0010
# train/epoch: 251.0000
#
# Step: 128800 (Training) Loss: 0.0000
# Step: 128832 (Training) Loss: 0.0000
# Step: 128864 (Training) Loss: 0.0000
# Step: 128896 (Training) Loss: 0.0000
# Step: 128928 (Training) Loss: 0.0000
# Step: 128960 (Training) Loss: 0.0000
# Step: 128992 (Training) Loss: 0.0000
# Step: 129024 (Training) Loss: 0.0000
#
# train/loss: 0.0000
# train/s_it: 0.0413
# train/lr: 0.0010
# train/epoch: 252.0000
#
# Step: 129024 (Validation) Batch: 0 / 128
# Step: 129024 (Validation) Batch: 32 / 128
# Step: 129024 (Validation) Batch: 64 / 128
# Step: 129024 (Validation) Batch: 96 / 128
#
# val/loss: 0.0000
# val/s_it: 0.0500
#
# Step: 129056 (Training) Loss: 0.0000
# Step: 129088 (Training) Loss: 0.0000
# Step: 129120 (Training) Loss: 0.0000
# Step: 129152 (Training) Loss: 0.0000
# Step: 129184 (Training) Loss: 0.0000
# Step: 129216 (Training) Loss: 0.0000
# Step: 129248 (Training) Loss: 0.0000
# Step: 129280 (Training) Loss: 0.0000
#
# train/loss: 0.0000
# train/s_it: 0.0308
# train/lr: 0.0010
# train/epoch: 252.0000
#
# Step: 129312 (Training) Loss: 0.0000
# Step: 129344 (Training) Loss: 0.0000
# Step: 129376 (Training) Loss: 0.0000
# Step: 129408 (Training) Loss: 0.0000
# Step: 129440 (Training) Loss: 0.0000
# Step: 129472 (Training) Loss: 0.0000
# Step: 129504 (Training) Loss: 0.0000
# Step: 129536 (Training) Loss: 0.0000
#
# train/loss: 0.0000
# train/s_it: 0.0418
# train/lr: 0.0010
# train/epoch: 253.0000
#
# Step: 129568 (Training) Loss: 0.0000
# Step: 129600 (Training) Loss: 0.0000
# Step: 129632 (Training) Loss: 0.0000
# Step: 129664 (Training) Loss: 0.0000
# Step: 129696 (Training) Loss: 0.0000
# Step: 129728 (Training) Loss: 0.0000
# Step: 129760 (Training) Loss: 0.0000
# Step: 129792 (Training) Loss: 0.0000
#
# train/loss: 0.0000
# train/s_it: 0.0302
# train/lr: 0.0010
# train/epoch: 253.0000
#
# Step: 129824 (Training) Loss: 0.0000
# Step: 129856 (Training) Loss: 0.0000
# Step: 129888 (Training) Loss: 0.0000
# Step: 129920 (Training) Loss: 0.0000
# Step: 129952 (Training) Loss: 0.0000
# Step: 129984 (Training) Loss: 0.0000
# Step: 130016 (Training) Loss: 0.0000
# Step: 130048 (Training) Loss: 0.0000
#
# train/loss: 0.0000
# train/s_it: 0.0418
# train/lr: 0.0010
# train/epoch: 254.0000
#
# Step: 130048 (Validation) Batch: 0 / 128
# Step: 130048 (Validation) Batch: 32 / 128
# Step: 130048 (Validation) Batch: 64 / 128
# Step: 130048 (Validation) Batch: 96 / 128
#
# val/loss: 0.0000
# val/s_it: 0.0417
#
# Step: 130080 (Training) Loss: 0.0000
# Step: 130112 (Training) Loss: 0.0000
# Step: 130144 (Training) Loss: 0.0000
# Step: 130176 (Training) Loss: 0.0000
# Step: 130208 (Training) Loss: 0.0000
# Step: 130240 (Training) Loss: 0.0000
# Step: 130272 (Training) Loss: 0.0000
# Step: 130304 (Training) Loss: 0.0000
#
# train/loss: 0.0000
# train/s_it: 0.0303
# train/lr: 0.0010
# train/epoch: 254.0000
#
# Step: 130336 (Training) Loss: 0.0000
# Step: 130368 (Training) Loss: 0.0000
# Step: 130400 (Training) Loss: 0.0000
# Step: 130432 (Training) Loss: 0.0000
# Step: 130464 (Training) Loss: 0.0000
# Step: 130496 (Training) Loss: 0.0000
# Step: 130528 (Training) Loss: 0.0000
# Step: 130560 (Training) Loss: 0.0000
#
# train/loss: 0.0000
# train/s_it: 0.0418
# train/lr: 0.0010
# train/epoch: 255.0000
#
# Step: 130592 (Training) Loss: 0.0000
# Step: 130624 (Training) Loss: 0.0000
# Step: 130656 (Training) Loss: 0.0000
# Step: 130688 (Training) Loss: 0.0000
# Step: 130720 (Training) Loss: 0.0000
# Step: 130752 (Training) Loss: 0.0000
# Step: 130784 (Training) Loss: 0.0000
# Step: 130816 (Training) Loss: 0.0000
#
# train/loss: 0.0000
# train/s_it: 0.0312
# train/lr: 0.0010
# train/epoch: 255.0000
#
# Step: 130848 (Training) Loss: 0.0000
# Step: 130880 (Training) Loss: 0.0000
# Step: 130912 (Training) Loss: 0.0000
# Step: 130944 (Training) Loss: 0.0000
# Step: 130976 (Training) Loss: 0.0000
# Step: 131008 (Training) Loss: 0.0000
# Step: 131040 (Training) Loss: 0.0000
# Stopping due to max_steps.
# Stopping due to max_steps.
